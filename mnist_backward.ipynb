# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import  input_data
import mnist_forward
import os

BATCH_SIZE = 256
LEARNING_RATE_BASE = 0.1
LEARNING_RATE_DECAY = 0.99
REGULARIZER = 0.0001
STEPS = 50000
MOVING_AVERAGE_DECAY = 0.99
MODEL_SAVE_PATH = "./model/"
MODEL_NAME = 'mnist_model'

def backward(mnist):
    
    x = tf.placeholder(tf.float32, [None, mnist_forward.INPUT_NODE])
    y_ = tf.placeholder(tf.float32,[None,mnist_forward.OUTPUT_NODE])
    y = mnist_forward.forward(x, REGULARIZER)
    global_step = tf.Variable(0, trainable = False)
    
    ce = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=y, labels=tf.argmax(y_, 1))
    cem = tf.reduce_mean(ce)
    loss = cem + tf.add_n(tf.get_collection("losses"))
    
    learning_rate = tf.train.exponential_decay(
                                LEARNING_RATE_BASE,
                                global_step,
                                mnist.train.num_examples / BATCH_SIZE,
                                LEARNING_RATE_DECAY,
                                staircase = True)
    
    train_step = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
    
    ema = tf.train.ExponentialMovingAverage(MOVING_AVERAGE_DECAY,global_step)
    ema_op = ema.apply(tf.trainable_variables())
    with tf.control_dependencies([train_step, ema_op]):
        train_op = tf.no_op(name="train")
        
    saver = tf.train.Saver()
    
    with tf.Session() as sess:
        init_op = tf.global_variables_initializer()
        sess.run(init_op)
        
        for i in range(STEPS):
            xs, ys = mnist.train.next_batch(BATCH_SIZE)
            _, loss_value, step = sess.run([train_op, loss, global_step], feed_dict={x:xs, y_: ys})
            if i % 1000 ==0:
                print("After %d training step(s), losses on trianing batch is %f. " %(step, loss_value))
                saver.save(sess, os.path.join(MODEL_SAVE_PATH,MODEL_NAME),global_step = global_step)
                
def main():
    mnist = input_data.read_data_sets("./MNIST_data/",one_hot= True)
    backward(mnist)
    
if __name__ == "__main__":
    main()
# Out:
# WARNING:tensorflow:From <ipython-input-2-be9e6f8d7eea>:54: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From D:\Users\lele\Anaconda3\envs\keras\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From D:\Users\lele\Anaconda3\envs\keras\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ./MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From D:\Users\lele\Anaconda3\envs\keras\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ./MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From D:\Users\lele\Anaconda3\envs\keras\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting ./MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ./MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From D:\Users\lele\Anaconda3\envs\keras\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# After 1 training step(s), losses on trianing batch is 2.860926.
# After 1001 training step(s), losses on trianing batch is 0.350883.
# After 2001 training step(s), losses on trianing batch is 0.265956.
# After 3001 training step(s), losses on trianing batch is 0.247919.
# After 4001 training step(s), losses on trianing batch is 0.218711.
# After 5001 training step(s), losses on trianing batch is 0.201225.
# After 6001 training step(s), losses on trianing batch is 0.207533.
# After 7001 training step(s), losses on trianing batch is 0.183419.
# After 8001 training step(s), losses on trianing batch is 0.182193.
# After 9001 training step(s), losses on trianing batch is 0.170735.
# After 10001 training step(s), losses on trianing batch is 0.188354.
# After 11001 training step(s), losses on trianing batch is 0.167919.
# After 12001 training step(s), losses on trianing batch is 0.174971.
# After 13001 training step(s), losses on trianing batch is 0.178794.
# After 14001 training step(s), losses on trianing batch is 0.167945.
# After 15001 training step(s), losses on trianing batch is 0.180192.
# After 16001 training step(s), losses on trianing batch is 0.169211.
# After 17001 training step(s), losses on trianing batch is 0.160823.
# After 18001 training step(s), losses on trianing batch is 0.148409.
# After 19001 training step(s), losses on trianing batch is 0.148997.
# After 20001 training step(s), losses on trianing batch is 0.155089.
# After 21001 training step(s), losses on trianing batch is 0.163209.
# After 22001 training step(s), losses on trianing batch is 0.149414.
# After 23001 training step(s), losses on trianing batch is 0.158236.
# After 24001 training step(s), losses on trianing batch is 0.147007.
# After 25001 training step(s), losses on trianing batch is 0.143372.
# After 26001 training step(s), losses on trianing batch is 0.146931.
# After 27001 training step(s), losses on trianing batch is 0.151124.
# After 28001 training step(s), losses on trianing batch is 0.142916.
# After 29001 training step(s), losses on trianing batch is 0.142049.
# After 30001 training step(s), losses on trianing batch is 0.137897.
# After 31001 training step(s), losses on trianing batch is 0.150624.
# After 32001 training step(s), losses on trianing batch is 0.149548.
# After 33001 training step(s), losses on trianing batch is 0.144256.
# After 34001 training step(s), losses on trianing batch is 0.147530.
# After 35001 training step(s), losses on trianing batch is 0.141618.
# After 36001 training step(s), losses on trianing batch is 0.137964.
# After 37001 training step(s), losses on trianing batch is 0.150764.
# After 38001 training step(s), losses on trianing batch is 0.140176.
# After 39001 training step(s), losses on trianing batch is 0.137057.
# After 40001 training step(s), losses on trianing batch is 0.135586.
# After 41001 training step(s), losses on trianing batch is 0.138417.
# After 42001 training step(s), losses on trianing batch is 0.139068.
# After 43001 training step(s), losses on trianing batch is 0.140603.
# After 44001 training step(s), losses on trianing batch is 0.140301.
# After 45001 training step(s), losses on trianing batch is 0.135959.
# After 46001 training step(s), losses on trianing batch is 0.134512.
# After 47001 training step(s), losses on trianing batch is 0.138384.
# After 48001 training step(s), losses on trianing batch is 0.131829.
# After 49001 training step(s), losses on trianing batch is 0.132271.

# %%
a = 23
b = 12
print("c:",a+b)
# Out:
# c: 35
